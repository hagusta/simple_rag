# %%
import pandas as pd

# %%
df = pd.read_csv("../data/qa.csv",index_col=["idx"])

# %%
df
# Out:
#                                                   text  text_id  \
# idx
# 0    Still, while condemning Plato, we must acknowl...      314
# 1    Still, while condemning Plato, we must acknowl...      314
# 2    Still, while condemning Plato, we must acknowl...      314
# 3    Still, while condemning Plato, we must acknowl...      314
# 4    Still, while condemning Plato, we must acknowl...      314
# ..                                                 ...      ...
# 70   Lastly, no one can have observed the first ris...      317
# 71   Lastly, no one can have observed the first ris...      317
# 72   Lastly, no one can have observed the first ris...      317
# 73   Thus far, as the argument required, we have sa...      251
# 74   Thus far, as the argument required, we have sa...      251
#
#                                               question  \
# idx
# 0    What social problem does the author acknowledg...
# 1    According to the text, what is the greatest hi...
# ...
